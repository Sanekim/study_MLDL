# %%
from model import resolve_single
from model.edsr import edsr

from utils import load_image, plot_sample

# %%
model = edsr(scale=4, num_res_blocks=16)
model.load_weights('weights/edsr-16-x4/weights.h5')

# %%
lr = load_image('demo/0851x4-crop.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/principal.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/principal_2.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/principal_3.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/principal_4.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-8-d510a8bacd2b> in <module>
#       1 lr = load_image('demo/principal_4.png')
# ----> 2 sr = resolve_single(model, lr)
#       3 plot_sample(lr, sr)
#
# D:\Python_Project\Super_TF2.0\super-resolution-master\model\common.py in resolve_single(model, lr)
#       7
#       8 def resolve_single(model, lr):
# ----> 9     return resolve(model, tf.expand_dims(lr, axis=0))[0]
#      10
#      11
#
# D:\Python_Project\Super_TF2.0\super-resolution-master\model\common.py in resolve(model, lr_batch)
#      12 def resolve(model, lr_batch):
#      13     lr_batch = tf.cast(lr_batch, tf.float32)
# ---> 14     sr_batch = model(lr_batch)
#      15     sr_batch = tf.clip_by_value(sr_batch, 0, 255)
#      16     sr_batch = tf.round(sr_batch)
#
# ...

# %%
lr = load_image('demo/pencil.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/sane.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/tsp.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-12-2b46e294ca3b> in <module>
#       1 lr = load_image('demo/tsp.png')
# ----> 2 sr = resolve_single(model, lr)
#       3 plot_sample(lr, sr)
#
# D:\Python_Project\Super_TF2.0\super-resolution-master\model\common.py in resolve_single(model, lr)
#       7
#       8 def resolve_single(model, lr):
# ----> 9     return resolve(model, tf.expand_dims(lr, axis=0))[0]
#      10
#      11
#
# D:\Python_Project\Super_TF2.0\super-resolution-master\model\common.py in resolve(model, lr_batch)
#      12 def resolve(model, lr_batch):
#      13     lr_batch = tf.cast(lr_batch, tf.float32)
# ---> 14     sr_batch = model(lr_batch)
#      15     sr_batch = tf.clip_by_value(sr_batch, 0, 255)
#      16     sr_batch = tf.round(sr_batch)
#
# ...

# %%
lr = load_image('demo/tsp_3.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/edsr.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)

# %%
lr = load_image('demo/dcm01.png')
sr = resolve_single(model, lr)
plot_sample(lr, sr)
